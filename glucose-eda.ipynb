# %%
import numpy as np
import pandas as pd

df = pd.read_csv("data/a.csv", skiprows=(0, 1))

df.head()
# Out:
#                  Gerät                          Seriennummer  \
# 0  FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
# 1  FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
# 2  FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
# 3  FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
# 4  FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
#
#   Gerätezeitstempel  Aufzeichnungstyp  Glukosewert-Verlauf mg/dL  \
# 0  18-02-2021 10:57                 0                       77.0
# 1  18-02-2021 11:12                 0                       78.0
# 2  18-02-2021 11:27                 0                       78.0
# 3  18-02-2021 11:42                 0                       76.0
# 4  18-02-2021 11:57                 0                       75.0
#
#    Glukose-Scan mg/dL  Nicht numerisches schnellwirkendes Insulin  \
# 0                 NaN                                         NaN
# 1                 NaN                                         NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1199 entries, 0 to 1198
# Data columns (total 19 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Gerät                                        1199 non-null   object
#  1   Seriennummer                                 1199 non-null   object
#  2   Gerätezeitstempel                            1199 non-null   object
#  3   Aufzeichnungstyp                             1199 non-null   int64
#  4   Glukosewert-Verlauf mg/dL                    1022 non-null   float64
#  5   Glukose-Scan mg/dL                           163 non-null    float64
#  6   Nicht numerisches schnellwirkendes Insulin   0 non-null      float64
#  7   Schnellwirkendes Insulin (Einheiten)         0 non-null      float64
#  8   Nicht numerische Nahrungsdaten               0 non-null      float64
# ...

# %%
df.nunique()
# Out:
# Gerät                                             1
# Seriennummer                                      1
# Gerätezeitstempel                              1180
# Aufzeichnungstyp                                  3
# Glukosewert-Verlauf mg/dL                        69
# Glukose-Scan mg/dL                               52
# Nicht numerisches schnellwirkendes Insulin        0
# Schnellwirkendes Insulin (Einheiten)              0
# Nicht numerische Nahrungsdaten                    0
# Kohlenhydrate (Gramm)                             0
# Kohlenhydrate (Portionen)                         0
# Nicht numerisches Depotinsulin                    0
# Depotinsulin (Einheiten)                          0
# Notizen                                           0
# Glukose-Teststreifen mg/dL                        0
# Keton mmol/L                                      0
# Mahlzeiteninsulin (Einheiten)                     0
# Korrekturinsulin (Einheiten)                      0
# ...

# %%
df.groupby(["Aufzeichnungstyp"]).count()
# Out:
#                   Gerät  Seriennummer  Gerätezeitstempel  \
# Aufzeichnungstyp
# 0                  1022          1022               1022
# 1                   163           163                163
# 6                    14            14                 14
#
#                   Glukosewert-Verlauf mg/dL  Glukose-Scan mg/dL  \
# Aufzeichnungstyp
# 0                                      1022                   0
# 1                                         0                 163
# 6                                         0                   0
#
#                   Nicht numerisches schnellwirkendes Insulin  \
# Aufzeichnungstyp
# 0                                                          0
# 1                                                          0
# 6                                                          0
#
#                   Schnellwirkendes Insulin (Einheiten)  \
# Aufzeichnungstyp
# 0                                                    0
# ...

# %%
df.Aufzeichnungstyp.unique()
# Out:
# array([0, 1, 6])

# %% [markdown]
# Types:
#  - 0: Glikosewert-Verlauf
#  - 1: Glukose-Scan
#  - 6: No Measurment (probably error)
